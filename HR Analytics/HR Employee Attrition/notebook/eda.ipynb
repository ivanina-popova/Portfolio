# %%
# Importing analysis and visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 
import numpy as np

# %%
# Chapter 1: Data Exploration

# %%
# Loading the dataset
df = pd.read_csv('../data/hr-employee-attrition.csv')
df.sample(10)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 505    26        No      Travel_Rarely        991  Research & Development
# 437    30        No      Travel_Rarely        413                   Sales
# 159    34        No  Travel_Frequently        303                   Sales
# 959    40        No      Travel_Rarely        523  Research & Development
# 486    37        No      Travel_Rarely        558                   Sales
# 1086   50        No  Travel_Frequently        333  Research & Development
# 1229   40        No      Travel_Rarely        369  Research & Development
# 541    36        No         Non-Travel        427  Research & Development
# 161    27        No         Non-Travel        691  Research & Development
# 890    54        No  Travel_Frequently        966  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 505                  6          3  Life Sciences              1
# ...

# %%
# Overview of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# Overview of the data - summary statistics
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
# Chapter 2: Data Preprocessing

# %%
# Handling duplicates
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Handling duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Check for unique values
def checkunique(data):
    nunique = data.apply(lambda col : col.nunique())
    unique = data.apply(lambda col : col.unique())
    result= pd.DataFrame(
        {
             'N-Unique' : nunique,
             'Unique' : unique
        }
    )
    return result

# %%
# Check for unique values
checkunique(df)
# Out:
#                           N-Unique  \
# Age                             43
# Attrition                        2
# BusinessTravel                   3
# DailyRate                      886
# Department                       3
# DistanceFromHome                29
# Education                        5
# EducationField                   6
# EmployeeCount                    1
# EmployeeNumber                1470
# EnvironmentSatisfaction          4
# Gender                           2
# HourlyRate                      71
# JobInvolvement                   4
# JobLevel                         5
# JobRole                          9
# JobSatisfaction                  4
# MaritalStatus                    3
# MonthlyIncome                 1349
# MonthlyRate                   1427
# NumCompaniesWorked              10
# Over18                           1
# OverTime                         2
# PercentSalaryHike               15
# PerformanceRating                2
# ...

# %%
# Removing unnecessary columns
df= df.drop(['EmployeeCount','Over18','StandardHours', 'EmployeeNumber','PerformanceRating'], axis=1)
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %%
# Checking for outliers
plt.figure(figsize=(16,10))
plt.subplot(1,2,1)
sns.scatterplot(df['MonthlyIncome'])
plt.subplot(1,2,2)
sns.boxplot(df)
plt.xticks(rotation=90)
plt.show()

# %%
# Deleting outliers with IQR
Q1= df['MonthlyIncome'].quantile(0.25)
Q3= df['MonthlyIncome'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR
clean_df=df[(df['MonthlyIncome']>=lower) & (df['MonthlyIncome']<=upper)]

clean_df.reset_index()
# Out:
#       index  Age Attrition     BusinessTravel  DailyRate  \
# 0         0   41       Yes      Travel_Rarely       1102
# 1         1   49        No  Travel_Frequently        279
# 2         2   37       Yes      Travel_Rarely       1373
# 3         3   33        No  Travel_Frequently       1392
# 4         4   27        No      Travel_Rarely        591
# ...     ...  ...       ...                ...        ...
# 1351   1465   36        No  Travel_Frequently        884
# 1352   1466   39        No      Travel_Rarely        613
# 1353   1467   27        No      Travel_Rarely        155
# 1354   1468   49        No  Travel_Frequently       1023
# 1355   1469   34        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# 1     Research & Development                 8          1  Life Sciences
# ...

# %%
# Post-cleaning validation
plt.figure(figsize=(16,10))
plt.subplot(1,2,1)
sns.scatterplot(clean_df['MonthlyIncome'])
plt.subplot(1,2,2)
sns.boxplot(clean_df)
plt.xticks(rotation=90)
plt.show()

print(f'Number of Rows Deleted: {df.shape[0] - clean_df.shape[0]}')
# Out:
# Number of Rows Deleted: 114

# %%
# Save the clean dataset
clean_df.to_csv('../data/clean_hr_employee_attrition.csv', index=False)
